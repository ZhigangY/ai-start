# %% [markdown]
# # 单卡GPU 进行 ChatGLM3-6B模型 LORA 高效微调
# 本 Cookbook 将带领开发者使用 `AdvertiseGen` 对 ChatGLM3-6B 数据集进行 lora微调，使其具备专业的广告生成能力。
#
# ## 硬件需求
# 显存：24GB及以上（推荐使用30系或A10等sm80架构以上的NVIDIA显卡进行尝试）
# 内存：16GB
# RAM: 2.9 /16 GB
# GPU RAM: 15.5/16.0 GB

# %% [markdown]
# ## 0. 环境检查
# 首先，先检查代码的运行地址，确保运行地址处于 `finetune_demo` 中。
# 并且，确保已经安装了 `requirements.txt`中的依赖。
#
# > 本 demo 中，不需要使用 deepspeed, mpi4py 两个依赖，如果您安装这两个依赖遇到问题，可以不安装这两个依赖。

# %% [markdown]
# ## 1. 准备数据集
# 我们使用 AdvertiseGen 数据集来进行微调。从 [Google Drive](https://drive.google.com/file/d/13_vf0xRTQsyneRKdD1bZIr93vBGOczrk/view?usp=sharing) 或者 [Tsinghua Cloud](https://cloud.tsinghua.edu.cn/f/b3f119a008264b1cabd1/?dl=1) 下载处理好的 AdvertiseGen 数据集，将解压后的 AdvertiseGen 目录放到本目录的 `/data/` 下

# %%
import json
from typing import Union
from pathlib import Path


def _resolve_path(path: Union[str, Path]) -> Path:
    return Path(path).expanduser().resolve()


def _mkdir(dir_name: Union[str, Path]):
    dir_name = _resolve_path(dir_name)
    if not dir_name.is_dir():
        dir_name.mkdir(parents=True, exist_ok=False)


def convert_adgen(data_dir: Union[str, Path], save_dir: Union[str, Path]):
    def _convert(in_file: Path, out_file: Path):
        _mkdir(out_file.parent)
        with open(in_file, encoding='utf-8') as fin:
            with open(out_file, 'wt', encoding='utf-8') as fout:
                for line in fin:
                    dct = json.loads(line)
                    sample = {'conversations': [{'role': 'user', 'content': dct['content']},
                                                {'role': 'assistant', 'content': dct['summary']}]}
                    fout.write(json.dumps(sample, ensure_ascii=False) + '\n')

    data_dir = _resolve_path(data_dir)
    save_dir = _resolve_path(save_dir)

    train_file = data_dir / 'train.json'
    if train_file.is_file():
        out_file = save_dir / train_file.relative_to(data_dir)
        _convert(train_file, out_file)

    dev_file = data_dir / 'dev.json'
    if dev_file.is_file():
        out_file = save_dir / dev_file.relative_to(data_dir)
        _convert(dev_file, out_file)


convert_adgen('data/AdvertiseGen', 'data/AdvertiseGen_fix')

# %% [markdown]
# ## 2. 使用命令行开始微调,我们使用 lora 进行微调
# 接着，我们仅需要将配置好的参数以命令行的形式传参给程序，就可以使用命令行进行高效微调。

# %%
#!CUDA_VISIBLE_DEVICES=0 NCCL_P2P_DISABLE="1" NCCL_IB_DISABLE="1" python finetune_hf.py  data/AdvertiseGen_fix  THUDM/chatglm3-6b  configs/lora.yaml
# !python finetune_hf.py data/AdvertiseGen_fix 'THUDM/chatglm3-6b' configs/lora.yaml
# Out:
# /root/anaconda3/envs/tf1/lib/python3.11/site-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Setting eos_token is not supported, use the default one.
# Setting pad_token is not supported, use the default one.
# Setting unk_token is not supported, use the default one.
# Loading checkpoint shards: 100%|██████████████████| 7/7 [00:01<00:00,  3.53it/s]
# trainable params: 1,949,696 || all params: 6,245,533,696 || trainable%: 0.031217444255383614
# --> Model
#
# --> model has 1.949696M params
#
# Setting num_proc from 16 back to 1 for the train split to disable multiprocessing as it only contains one shard.
# Generating train split: 114599 examples [00:00, 464144.60 examples/s]
# Setting num_proc from 16 back to 1 for the validation split to disable multiprocessing as it only contains one shard.
# Generating validation split: 1070 examples [00:00, 83412.11 examples/s]
# Setting num_proc from 16 back to 1 for the test split to disable multiprocessing as it only contains one shard.
# Generating test split: 1070 examples [00:00, 84690.24 examples/s]
# Map (num_proc=16): 100%|██████| 114599/114599 [00:02<00:00, 43988.85 examples/s]
# train_dataset: Dataset({
#     features: ['input_ids', 'labels'],
#     num_rows: 114599
# })
# Map (num_proc=16): 100%|███████████| 1070/1070 [00:01<00:00, 1040.57 examples/s]
# val_dataset: Dataset({
#     features: ['input_ids', 'output_ids'],
#     num_rows: 1070
# })
# Map (num_proc=16): 100%|███████████| 1070/1070 [00:01<00:00, 1057.58 examples/s]
# test_dataset: Dataset({
#     features: ['input_ids', 'output_ids'],
#     num_rows: 1070
# })
# --> Sanity check
#            '[gMASK]': 64790 -> -100
#                'sop': 64792 -> -100
#           '<|user|>': 64795 -> -100
#                   '': 30910 -> -100
#                 '\n': 13 -> -100
#                   '': 30910 -> -100
#                 '类型': 33467 -> -100
#                  '#': 31010 -> -100
#                  '裤': 56532 -> -100
#                  '*': 30998 -> -100
#                  '版': 55090 -> -100
#                  '型': 54888 -> -100
#                  '#': 31010 -> -100
#                 '宽松': 40833 -> -100
#                  '*': 30998 -> -100
#                 '风格': 32799 -> -100
#                  '#': 31010 -> -100
#                 '性感': 40589 -> -100
#                  '*': 30998 -> -100
#                 '图案': 37505 -> -100
#                  '#': 31010 -> -100
#                 '线条': 37216 -> -100
#                  '*': 30998 -> -100
#                  '裤': 56532 -> -100
#                  '型': 54888 -> -100
#                  '#': 31010 -> -100
#                  '阔': 56529 -> -100
#                  '腿': 56158 -> -100
#                  '裤': 56532 -> -100
#      '<|assistant|>': 64796 -> -100
#                   '': 30910 -> 30910
#                 '\n': 13 -> 13
#                   '': 30910 -> 30910
#                 '宽松': 40833 -> 40833
#                  '的': 54530 -> 54530
#                  '阔': 56529 -> 56529
#                  '腿': 56158 -> 56158
#                  '裤': 56532 -> 56532
#                  '这': 54551 -> 54551
#                 '两年': 33808 -> 33808
#                 '真的': 32041 -> 32041
#                  '吸': 55360 -> 55360
#                  '粉': 55486 -> 55486
#                 '不少': 32138 -> 32138
#                  '，': 31123 -> 31123
#                 '明星': 32943 -> 32943
#                 '时尚': 33481 -> 33481
#                  '达': 54880 -> 54880
#                 '人的': 31664 -> 31664
#                 '心头': 46565 -> 46565
#                  '爱': 54799 -> 54799
#                  '。': 31155 -> 31155
#                 '毕竟': 33051 -> 33051
#                  '好': 54591 -> 54591
#                  '穿': 55432 -> 55432
#                 '时尚': 33481 -> 33481
#                  '，': 31123 -> 31123
#                  '谁': 55622 -> 55622
#                 '都能': 32904 -> 32904
#                  '穿': 55432 -> 55432
#                  '出': 54557 -> 54557
#                  '腿': 56158 -> 56158
#                  '长': 54625 -> 54625
#                  '2': 30943 -> 30943
#                  '米': 55055 -> 55055
#                '的效果': 35590 -> 35590
#                 '宽松': 40833 -> 40833
#                  '的': 54530 -> 54530
#                  '裤': 56532 -> 56532
#                  '腿': 56158 -> 56158
#                  '，': 31123 -> 31123
#                '当然是': 48466 -> 48466
#                  '遮': 57148 -> 57148
#                  '肉': 55343 -> 55343
#                  '小': 54603 -> 54603
#                 '能手': 49355 -> 49355
#                  '啊': 55674 -> 55674
#                  '。': 31155 -> 31155
#                 '上身': 51605 -> 51605
#                  '随': 55119 -> 55119
#                  '性': 54642 -> 54642
#                 '自然': 31799 -> 31799
#                  '不': 54535 -> 54535
#                  '拘': 57036 -> 57036
#                  '束': 55625 -> 55625
#                  '，': 31123 -> 31123
#                 '面料': 46839 -> 46839
#                  '亲': 55113 -> 55113
#                  '肤': 56089 -> 56089
#                 '舒适': 33894 -> 33894
#                  '贴': 55778 -> 55778
#                 '身体': 31902 -> 31902
#                  '验': 55017 -> 55017
#                  '感': 54706 -> 54706
#                  '棒': 56382 -> 56382
#                  '棒': 56382 -> 56382
#                  '哒': 59230 -> 59230
#                  '。': 31155 -> 31155
#                  '系': 54712 -> 54712
#                  '带': 54882 -> 54882
#                 '部分': 31726 -> 31726
#                 '增加': 31917 -> 31917
#                 '设计': 31735 -> 31735
#                 '看点': 45032 -> 45032
#                  '，': 31123 -> 31123
#                  '还': 54656 -> 54656
#                  '让': 54772 -> 54772
#                 '单品': 46539 -> 46539
#                '的设计': 34481 -> 34481
#                  '感': 54706 -> 54706
#                 '更强': 43084 -> 43084
#                  '。': 31155 -> 31155
#                 '腿部': 46799 -> 46799
#                 '线条': 37216 -> 37216
#                  '若': 55351 -> 55351
#                  '隐': 55733 -> 55733
#                  '若': 55351 -> 55351
#                  '现': 54600 -> 54600
#                  '的': 54530 -> 54530
#                  '，': 31123 -> 31123
#                 '性感': 40589 -> 40589
#                  '撩': 58521 -> 58521
#                  '人': 54533 -> 54533
#                  '。': 31155 -> 31155
#                 '颜色': 33692 -> 33692
#                  '敲': 57004 -> 57004
#                 '温柔': 34678 -> 34678
#                  '的': 54530 -> 54530
#                  '，': 31123 -> 31123
#                  '与': 54619 -> 54619
#                 '裤子': 44722 -> 44722
#                 '本身': 32754 -> 32754
#                  '所': 54626 -> 54626
#                 '呈现': 33169 -> 33169
#                '的风格': 48084 -> 48084
#                 '有点': 33149 -> 33149
#                  '反': 54955 -> 54955
#                  '差': 55342 -> 55342
#                  '萌': 56842 -> 56842
#                  '。': 31155 -> 31155
#                   '': 2 -> 2
# max_steps is given, it will override any value given in num_train_epochs
# ***** Running training *****
#   Num examples = 114,599
#   Num Epochs = 1
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 1
#   Total optimization steps = 3,000
#   Number of trainable parameters = 1,949,696
# {'loss': 4.8934, 'learning_rate': 4.9833333333333336e-05, 'epoch': 0.0}
# {'loss': 4.7328, 'learning_rate': 4.966666666666667e-05, 'epoch': 0.0}
# {'loss': 4.6063, 'learning_rate': 4.9500000000000004e-05, 'epoch': 0.0}
# {'loss': 4.1531, 'learning_rate': 4.933333333333334e-05, 'epoch': 0.0}
# {'loss': 4.0379, 'learning_rate': 4.9166666666666665e-05, 'epoch': 0.0}
# {'loss': 3.9969, 'learning_rate': 4.9e-05, 'epoch': 0.0}
# {'loss': 3.9303, 'learning_rate': 4.883333333333334e-05, 'epoch': 0.0}
# {'loss': 3.9084, 'learning_rate': 4.866666666666667e-05, 'epoch': 0.0}
# {'loss': 3.735, 'learning_rate': 4.85e-05, 'epoch': 0.0}
# {'loss': 3.7053, 'learning_rate': 4.8333333333333334e-05, 'epoch': 0.0}
# {'loss': 3.6354, 'learning_rate': 4.8166666666666674e-05, 'epoch': 0.0}
# {'loss': 3.6301, 'learning_rate': 4.8e-05, 'epoch': 0.0}
# {'loss': 3.6961, 'learning_rate': 4.7833333333333335e-05, 'epoch': 0.0}
# {'loss': 3.6859, 'learning_rate': 4.766666666666667e-05, 'epoch': 0.0}
# {'loss': 3.6875, 'learning_rate': 4.75e-05, 'epoch': 0.01}
# {'loss': 3.6252, 'learning_rate': 4.7333333333333336e-05, 'epoch': 0.01}
# {'loss': 3.5734, 'learning_rate': 4.716666666666667e-05, 'epoch': 0.01}
# {'loss': 3.627, 'learning_rate': 4.7e-05, 'epoch': 0.01}
# {'loss': 3.5596, 'learning_rate': 4.683333333333334e-05, 'epoch': 0.01}
# {'loss': 3.6176, 'learning_rate': 4.666666666666667e-05, 'epoch': 0.01}
# {'loss': 3.5607, 'learning_rate': 4.6500000000000005e-05, 'epoch': 0.01}
# {'loss': 3.5426, 'learning_rate': 4.633333333333333e-05, 'epoch': 0.01}
# {'loss': 3.5129, 'learning_rate': 4.6166666666666666e-05, 'epoch': 0.01}
# {'loss': 3.4855, 'learning_rate': 4.600000000000001e-05, 'epoch': 0.01}
# {'loss': 3.5451, 'learning_rate': 4.5833333333333334e-05, 'epoch': 0.01}
# {'loss': 3.5596, 'learning_rate': 4.566666666666667e-05, 'epoch': 0.01}
# {'loss': 3.5602, 'learning_rate': 4.55e-05, 'epoch': 0.01}
# {'loss': 3.625, 'learning_rate': 4.5333333333333335e-05, 'epoch': 0.01}
# {'loss': 3.4576, 'learning_rate': 4.516666666666667e-05, 'epoch': 0.01}
# {'loss': 3.4914, 'learning_rate': 4.5e-05, 'epoch': 0.01}
# {'loss': 3.5387, 'learning_rate': 4.483333333333333e-05, 'epoch': 0.01}
# {'loss': 3.5734, 'learning_rate': 4.466666666666667e-05, 'epoch': 0.01}
# {'loss': 3.5398, 'learning_rate': 4.4500000000000004e-05, 'epoch': 0.01}
# {'loss': 3.4547, 'learning_rate': 4.433333333333334e-05, 'epoch': 0.01}
# {'loss': 3.6137, 'learning_rate': 4.4166666666666665e-05, 'epoch': 0.01}
# {'loss': 3.5686, 'learning_rate': 4.4000000000000006e-05, 'epoch': 0.01}
# {'loss': 3.5264, 'learning_rate': 4.383333333333334e-05, 'epoch': 0.01}
# {'loss': 3.6355, 'learning_rate': 4.3666666666666666e-05, 'epoch': 0.01}
# {'loss': 3.45, 'learning_rate': 4.35e-05, 'epoch': 0.01}
# {'loss': 3.4439, 'learning_rate': 4.3333333333333334e-05, 'epoch': 0.01}
# {'loss': 3.3949, 'learning_rate': 4.316666666666667e-05, 'epoch': 0.01}
# {'loss': 3.4822, 'learning_rate': 4.3e-05, 'epoch': 0.01}
# {'loss': 3.3383, 'learning_rate': 4.2833333333333335e-05, 'epoch': 0.02}
# {'loss': 3.5891, 'learning_rate': 4.266666666666667e-05, 'epoch': 0.02}
# {'loss': 3.5879, 'learning_rate': 4.25e-05, 'epoch': 0.02}
# {'loss': 3.4469, 'learning_rate': 4.233333333333334e-05, 'epoch': 0.02}
# {'loss': 3.4797, 'learning_rate': 4.216666666666667e-05, 'epoch': 0.02}
# {'loss': 3.4896, 'learning_rate': 4.2e-05, 'epoch': 0.02}
# {'loss': 3.3893, 'learning_rate': 4.183333333333334e-05, 'epoch': 0.02}
# {'loss': 3.4705, 'learning_rate': 4.166666666666667e-05, 'epoch': 0.02}
#  17%|██████▋                                 | 500/3000 [05:13<24:56,  1.67it/s]***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:03<00:03,  1.66s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:19<00:07,  7.72s/it]
# 100%|█████████████████████████████████████████████| 4/4 [00:22<00:00,  5.98s/it]Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.737 seconds.
# Prefix dict has been built successfully.
#
# {'eval_rouge-1': 30.479592000000004, 'eval_rouge-2': 6.328837999999999, 'eval_rouge-l': 24.530012000000003, 'eval_bleu-4': 0.03161664885525038, 'eval_runtime': 27.037, 'eval_samples_per_second': 1.849, 'eval_steps_per_second': 0.148, 'epoch': 0.02}
#  17%|██████▋                                 | 500/3000 [05:40<24:56,  1.67it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:23<00:00,  5.98s/it]
#                                                                                 Saving model checkpoint to ./output/tmp-checkpoint-500
# {'loss': 3.4697, 'learning_rate': 4.15e-05, 'epoch': 0.02}
# {'loss': 3.5039, 'learning_rate': 4.133333333333333e-05, 'epoch': 0.02}
# {'loss': 3.6195, 'learning_rate': 4.116666666666667e-05, 'epoch': 0.02}
# {'loss': 3.4547, 'learning_rate': 4.1e-05, 'epoch': 0.02}
# {'loss': 3.473, 'learning_rate': 4.0833333333333334e-05, 'epoch': 0.02}
# {'loss': 3.408, 'learning_rate': 4.066666666666667e-05, 'epoch': 0.02}
# {'loss': 3.5172, 'learning_rate': 4.05e-05, 'epoch': 0.02}
# {'loss': 3.4412, 'learning_rate': 4.0333333333333336e-05, 'epoch': 0.02}
# {'loss': 3.4311, 'learning_rate': 4.016666666666667e-05, 'epoch': 0.02}
# {'loss': 3.4268, 'learning_rate': 4e-05, 'epoch': 0.02}
# {'loss': 3.5703, 'learning_rate': 3.983333333333333e-05, 'epoch': 0.02}
# {'loss': 3.5152, 'learning_rate': 3.966666666666667e-05, 'epoch': 0.02}
# {'loss': 3.5695, 'learning_rate': 3.9500000000000005e-05, 'epoch': 0.02}
# {'loss': 3.5488, 'learning_rate': 3.933333333333333e-05, 'epoch': 0.02}
# {'loss': 3.5947, 'learning_rate': 3.9166666666666665e-05, 'epoch': 0.02}
# {'loss': 3.5287, 'learning_rate': 3.9000000000000006e-05, 'epoch': 0.02}
# {'loss': 3.4324, 'learning_rate': 3.883333333333333e-05, 'epoch': 0.02}
# {'loss': 3.3963, 'learning_rate': 3.866666666666667e-05, 'epoch': 0.02}
# {'loss': 3.4535, 'learning_rate': 3.85e-05, 'epoch': 0.02}
# {'loss': 3.4352, 'learning_rate': 3.8333333333333334e-05, 'epoch': 0.02}
# {'loss': 3.3807, 'learning_rate': 3.816666666666667e-05, 'epoch': 0.02}
# {'loss': 3.4803, 'learning_rate': 3.8e-05, 'epoch': 0.03}
# {'loss': 3.4465, 'learning_rate': 3.7833333333333336e-05, 'epoch': 0.03}
# {'loss': 3.4201, 'learning_rate': 3.766666666666667e-05, 'epoch': 0.03}
# {'loss': 3.3902, 'learning_rate': 3.7500000000000003e-05, 'epoch': 0.03}
# {'loss': 3.4082, 'learning_rate': 3.733333333333334e-05, 'epoch': 0.03}
# {'loss': 3.5699, 'learning_rate': 3.7166666666666664e-05, 'epoch': 0.03}
# {'loss': 3.4408, 'learning_rate': 3.7e-05, 'epoch': 0.03}
# {'loss': 3.4729, 'learning_rate': 3.683333333333334e-05, 'epoch': 0.03}
# {'loss': 3.4957, 'learning_rate': 3.6666666666666666e-05, 'epoch': 0.03}
# {'loss': 3.4904, 'learning_rate': 3.65e-05, 'epoch': 0.03}
# {'loss': 3.6166, 'learning_rate': 3.633333333333333e-05, 'epoch': 0.03}
# {'loss': 3.39, 'learning_rate': 3.6166666666666674e-05, 'epoch': 0.03}
# {'loss': 3.5338, 'learning_rate': 3.6e-05, 'epoch': 0.03}
# {'loss': 3.4037, 'learning_rate': 3.5833333333333335e-05, 'epoch': 0.03}
# {'loss': 3.4223, 'learning_rate': 3.566666666666667e-05, 'epoch': 0.03}
# {'loss': 3.3941, 'learning_rate': 3.55e-05, 'epoch': 0.03}
# {'loss': 3.5402, 'learning_rate': 3.5333333333333336e-05, 'epoch': 0.03}
# {'loss': 3.3984, 'learning_rate': 3.516666666666667e-05, 'epoch': 0.03}
# {'loss': 3.3916, 'learning_rate': 3.5e-05, 'epoch': 0.03}
# {'loss': 3.5461, 'learning_rate': 3.483333333333334e-05, 'epoch': 0.03}
# {'loss': 3.4367, 'learning_rate': 3.466666666666667e-05, 'epoch': 0.03}
# {'loss': 3.4207, 'learning_rate': 3.45e-05, 'epoch': 0.03}
# {'loss': 3.3498, 'learning_rate': 3.433333333333333e-05, 'epoch': 0.03}
# {'loss': 3.4396, 'learning_rate': 3.4166666666666666e-05, 'epoch': 0.03}
# {'loss': 3.4813, 'learning_rate': 3.4000000000000007e-05, 'epoch': 0.03}
# {'loss': 3.4166, 'learning_rate': 3.3833333333333334e-05, 'epoch': 0.03}
# {'loss': 3.2785, 'learning_rate': 3.366666666666667e-05, 'epoch': 0.03}
# {'loss': 3.3482, 'learning_rate': 3.35e-05, 'epoch': 0.03}
# {'loss': 3.4719, 'learning_rate': 3.3333333333333335e-05, 'epoch': 0.03}
#  33%|█████████████                          | 1000/3000 [10:58<21:29,  1.55it/s]***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:16<00:16,  8.14s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:32<00:11, 11.52s/it]
#
# {'eval_rouge-1': 31.18391, 'eval_rouge-2': 7.045138000000001, 'eval_rouge-l': 24.50058, 'eval_bleu-4': 0.034736566985801985, 'eval_runtime': 51.3511, 'eval_samples_per_second': 0.974, 'eval_steps_per_second': 0.078, 'epoch': 0.03}
#  33%|█████████████                          | 1000/3000 [11:50<21:29,  1.55it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:34<00:00,  7.82s/it]
#                                                                                 Saving model checkpoint to ./output/tmp-checkpoint-1000
# {'loss': 3.3197, 'learning_rate': 3.316666666666667e-05, 'epoch': 0.04}
# {'loss': 3.3248, 'learning_rate': 3.3e-05, 'epoch': 0.04}
# {'loss': 3.3752, 'learning_rate': 3.283333333333333e-05, 'epoch': 0.04}
# {'loss': 3.5348, 'learning_rate': 3.266666666666667e-05, 'epoch': 0.04}
# {'loss': 3.4777, 'learning_rate': 3.2500000000000004e-05, 'epoch': 0.04}
# {'loss': 3.4123, 'learning_rate': 3.233333333333333e-05, 'epoch': 0.04}
# {'loss': 3.4109, 'learning_rate': 3.2166666666666665e-05, 'epoch': 0.04}
# {'loss': 3.4, 'learning_rate': 3.2000000000000005e-05, 'epoch': 0.04}
# {'loss': 3.3594, 'learning_rate': 3.183333333333334e-05, 'epoch': 0.04}
# {'loss': 3.5033, 'learning_rate': 3.1666666666666666e-05, 'epoch': 0.04}
# {'loss': 3.4572, 'learning_rate': 3.15e-05, 'epoch': 0.04}
# {'loss': 3.4535, 'learning_rate': 3.1333333333333334e-05, 'epoch': 0.04}
# {'loss': 3.3943, 'learning_rate': 3.116666666666667e-05, 'epoch': 0.04}
# {'loss': 3.4336, 'learning_rate': 3.1e-05, 'epoch': 0.04}
# {'loss': 3.418, 'learning_rate': 3.0833333333333335e-05, 'epoch': 0.04}
# {'loss': 3.3238, 'learning_rate': 3.066666666666667e-05, 'epoch': 0.04}
# {'loss': 3.3828, 'learning_rate': 3.05e-05, 'epoch': 0.04}
# {'loss': 3.3459, 'learning_rate': 3.0333333333333337e-05, 'epoch': 0.04}
# {'loss': 3.2912, 'learning_rate': 3.016666666666667e-05, 'epoch': 0.04}
# {'loss': 3.4859, 'learning_rate': 3e-05, 'epoch': 0.04}
# {'loss': 3.4637, 'learning_rate': 2.9833333333333335e-05, 'epoch': 0.04}
# {'loss': 3.4312, 'learning_rate': 2.9666666666666672e-05, 'epoch': 0.04}
# {'loss': 3.3996, 'learning_rate': 2.95e-05, 'epoch': 0.04}
# {'loss': 3.4152, 'learning_rate': 2.9333333333333336e-05, 'epoch': 0.04}
# {'loss': 3.4279, 'learning_rate': 2.916666666666667e-05, 'epoch': 0.04}
# {'loss': 3.4471, 'learning_rate': 2.9e-05, 'epoch': 0.04}
# {'loss': 3.4322, 'learning_rate': 2.8833333333333334e-05, 'epoch': 0.04}
# {'loss': 3.5033, 'learning_rate': 2.8666666666666668e-05, 'epoch': 0.04}
# {'loss': 3.3076, 'learning_rate': 2.8499999999999998e-05, 'epoch': 0.05}
# {'loss': 3.3633, 'learning_rate': 2.8333333333333335e-05, 'epoch': 0.05}
# {'loss': 3.4641, 'learning_rate': 2.816666666666667e-05, 'epoch': 0.05}
# {'loss': 3.3225, 'learning_rate': 2.8000000000000003e-05, 'epoch': 0.05}
# {'loss': 3.4512, 'learning_rate': 2.7833333333333333e-05, 'epoch': 0.05}
# {'loss': 3.4611, 'learning_rate': 2.7666666666666667e-05, 'epoch': 0.05}
# {'loss': 3.5861, 'learning_rate': 2.7500000000000004e-05, 'epoch': 0.05}
# {'loss': 3.1758, 'learning_rate': 2.733333333333333e-05, 'epoch': 0.05}
# {'loss': 3.635, 'learning_rate': 2.716666666666667e-05, 'epoch': 0.05}
# {'loss': 3.3709, 'learning_rate': 2.7000000000000002e-05, 'epoch': 0.05}
# {'loss': 3.2701, 'learning_rate': 2.6833333333333333e-05, 'epoch': 0.05}
# {'loss': 3.3607, 'learning_rate': 2.6666666666666667e-05, 'epoch': 0.05}
# {'loss': 3.4154, 'learning_rate': 2.6500000000000004e-05, 'epoch': 0.05}
# {'loss': 3.2805, 'learning_rate': 2.633333333333333e-05, 'epoch': 0.05}
# {'loss': 3.3687, 'learning_rate': 2.6166666666666668e-05, 'epoch': 0.05}
# {'loss': 3.2547, 'learning_rate': 2.6000000000000002e-05, 'epoch': 0.05}
# {'loss': 3.3406, 'learning_rate': 2.5833333333333336e-05, 'epoch': 0.05}
# {'loss': 3.4004, 'learning_rate': 2.5666666666666666e-05, 'epoch': 0.05}
# {'loss': 3.4084, 'learning_rate': 2.5500000000000003e-05, 'epoch': 0.05}
# {'loss': 3.4381, 'learning_rate': 2.5333333333333337e-05, 'epoch': 0.05}
# {'loss': 3.4797, 'learning_rate': 2.5166666666666667e-05, 'epoch': 0.05}
# {'loss': 3.3535, 'learning_rate': 2.5e-05, 'epoch': 0.05}
#  50%|███████████████████▌                   | 1500/3000 [17:07<15:46,  1.58it/s]***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:16<00:16,  8.17s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:32<00:11, 11.55s/it]
#
# {'eval_rouge-1': 32.70293, 'eval_rouge-2': 7.416650000000001, 'eval_rouge-l': 23.313694, 'eval_bleu-4': 0.03232916276650501, 'eval_runtime': 66.4744, 'eval_samples_per_second': 0.752, 'eval_steps_per_second': 0.06, 'epoch': 0.05}
#  50%|███████████████████▌                   | 1500/3000 [18:13<15:46,  1.58it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:49<00:00, 13.39s/it]
#                                                                                 Saving model checkpoint to ./output/tmp-checkpoint-1500
# {'loss': 3.3203, 'learning_rate': 2.4833333333333335e-05, 'epoch': 0.05}
# {'loss': 3.3072, 'learning_rate': 2.466666666666667e-05, 'epoch': 0.05}
# {'loss': 3.3227, 'learning_rate': 2.45e-05, 'epoch': 0.05}
# {'loss': 3.3684, 'learning_rate': 2.4333333333333336e-05, 'epoch': 0.05}
# {'loss': 3.3621, 'learning_rate': 2.4166666666666667e-05, 'epoch': 0.05}
# {'loss': 3.4295, 'learning_rate': 2.4e-05, 'epoch': 0.05}
# {'loss': 3.3928, 'learning_rate': 2.3833333333333334e-05, 'epoch': 0.05}
# {'loss': 3.5201, 'learning_rate': 2.3666666666666668e-05, 'epoch': 0.06}
# {'loss': 3.4246, 'learning_rate': 2.35e-05, 'epoch': 0.06}
# {'loss': 3.4787, 'learning_rate': 2.3333333333333336e-05, 'epoch': 0.06}
# {'loss': 3.3916, 'learning_rate': 2.3166666666666666e-05, 'epoch': 0.06}
# {'loss': 3.3652, 'learning_rate': 2.3000000000000003e-05, 'epoch': 0.06}
# {'loss': 3.407, 'learning_rate': 2.2833333333333334e-05, 'epoch': 0.06}
# {'loss': 3.2207, 'learning_rate': 2.2666666666666668e-05, 'epoch': 0.06}
# {'loss': 3.3955, 'learning_rate': 2.25e-05, 'epoch': 0.06}
# {'loss': 3.415, 'learning_rate': 2.2333333333333335e-05, 'epoch': 0.06}
# {'loss': 3.5562, 'learning_rate': 2.216666666666667e-05, 'epoch': 0.06}
# {'loss': 3.3922, 'learning_rate': 2.2000000000000003e-05, 'epoch': 0.06}
# {'loss': 3.3354, 'learning_rate': 2.1833333333333333e-05, 'epoch': 0.06}
# {'loss': 3.3723, 'learning_rate': 2.1666666666666667e-05, 'epoch': 0.06}
# {'loss': 3.3873, 'learning_rate': 2.15e-05, 'epoch': 0.06}
# {'loss': 3.5186, 'learning_rate': 2.1333333333333335e-05, 'epoch': 0.06}
# {'loss': 3.615, 'learning_rate': 2.116666666666667e-05, 'epoch': 0.06}
# {'loss': 3.3643, 'learning_rate': 2.1e-05, 'epoch': 0.06}
# {'loss': 3.3262, 'learning_rate': 2.0833333333333336e-05, 'epoch': 0.06}
# {'loss': 3.465, 'learning_rate': 2.0666666666666666e-05, 'epoch': 0.06}
# {'loss': 3.2979, 'learning_rate': 2.05e-05, 'epoch': 0.06}
# {'loss': 3.4215, 'learning_rate': 2.0333333333333334e-05, 'epoch': 0.06}
# {'loss': 3.2943, 'learning_rate': 2.0166666666666668e-05, 'epoch': 0.06}
# {'loss': 3.5045, 'learning_rate': 2e-05, 'epoch': 0.06}
# {'loss': 3.2758, 'learning_rate': 1.9833333333333335e-05, 'epoch': 0.06}
# {'loss': 3.2936, 'learning_rate': 1.9666666666666666e-05, 'epoch': 0.06}
# {'loss': 3.5104, 'learning_rate': 1.9500000000000003e-05, 'epoch': 0.06}
# {'loss': 3.3529, 'learning_rate': 1.9333333333333333e-05, 'epoch': 0.06}
# {'loss': 3.4283, 'learning_rate': 1.9166666666666667e-05, 'epoch': 0.06}
# {'loss': 3.3557, 'learning_rate': 1.9e-05, 'epoch': 0.06}
# {'loss': 3.4369, 'learning_rate': 1.8833333333333335e-05, 'epoch': 0.07}
# {'loss': 3.4293, 'learning_rate': 1.866666666666667e-05, 'epoch': 0.07}
# {'loss': 3.3674, 'learning_rate': 1.85e-05, 'epoch': 0.07}
# {'loss': 3.365, 'learning_rate': 1.8333333333333333e-05, 'epoch': 0.07}
# {'loss': 3.4449, 'learning_rate': 1.8166666666666667e-05, 'epoch': 0.07}
# {'loss': 3.4205, 'learning_rate': 1.8e-05, 'epoch': 0.07}
# {'loss': 3.3934, 'learning_rate': 1.7833333333333334e-05, 'epoch': 0.07}
# {'loss': 3.3332, 'learning_rate': 1.7666666666666668e-05, 'epoch': 0.07}
# {'loss': 3.425, 'learning_rate': 1.75e-05, 'epoch': 0.07}
# {'loss': 3.3545, 'learning_rate': 1.7333333333333336e-05, 'epoch': 0.07}
# {'loss': 3.5547, 'learning_rate': 1.7166666666666666e-05, 'epoch': 0.07}
# {'loss': 3.29, 'learning_rate': 1.7000000000000003e-05, 'epoch': 0.07}
# {'loss': 3.2469, 'learning_rate': 1.6833333333333334e-05, 'epoch': 0.07}
# {'loss': 3.3799, 'learning_rate': 1.6666666666666667e-05, 'epoch': 0.07}
#  67%|██████████████████████████             | 2000/3000 [23:26<10:46,  1.55it/s]***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:16<00:16,  8.17s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:32<00:11, 11.54s/it]
#
# {'eval_rouge-1': 31.708052, 'eval_rouge-2': 7.115452, 'eval_rouge-l': 23.398384, 'eval_bleu-4': 0.03227707195150414, 'eval_runtime': 51.8041, 'eval_samples_per_second': 0.965, 'eval_steps_per_second': 0.077, 'epoch': 0.07}
#  67%|██████████████████████████             | 2000/3000 [24:18<10:46,  1.55it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:34<00:00,  7.93s/it]
#                                                                                 Saving model checkpoint to ./output/tmp-checkpoint-2000
# {'loss': 3.493, 'learning_rate': 1.65e-05, 'epoch': 0.07}
# {'loss': 3.2844, 'learning_rate': 1.6333333333333335e-05, 'epoch': 0.07}
# {'loss': 3.2055, 'learning_rate': 1.6166666666666665e-05, 'epoch': 0.07}
# {'loss': 3.4605, 'learning_rate': 1.6000000000000003e-05, 'epoch': 0.07}
# {'loss': 3.3414, 'learning_rate': 1.5833333333333333e-05, 'epoch': 0.07}
# {'loss': 3.5187, 'learning_rate': 1.5666666666666667e-05, 'epoch': 0.07}
# {'loss': 3.2836, 'learning_rate': 1.55e-05, 'epoch': 0.07}
# {'loss': 3.2336, 'learning_rate': 1.5333333333333334e-05, 'epoch': 0.07}
# {'loss': 3.3602, 'learning_rate': 1.5166666666666668e-05, 'epoch': 0.07}
# {'loss': 3.5463, 'learning_rate': 1.5e-05, 'epoch': 0.07}
# {'loss': 3.3994, 'learning_rate': 1.4833333333333336e-05, 'epoch': 0.07}
# {'loss': 3.4793, 'learning_rate': 1.4666666666666668e-05, 'epoch': 0.07}
# {'loss': 3.3549, 'learning_rate': 1.45e-05, 'epoch': 0.07}
# {'loss': 3.2619, 'learning_rate': 1.4333333333333334e-05, 'epoch': 0.07}
# {'loss': 3.5338, 'learning_rate': 1.4166666666666668e-05, 'epoch': 0.08}
# {'loss': 3.4004, 'learning_rate': 1.4000000000000001e-05, 'epoch': 0.08}
# {'loss': 3.3412, 'learning_rate': 1.3833333333333334e-05, 'epoch': 0.08}
# {'loss': 3.3281, 'learning_rate': 1.3666666666666666e-05, 'epoch': 0.08}
# {'loss': 3.365, 'learning_rate': 1.3500000000000001e-05, 'epoch': 0.08}
# {'loss': 3.2975, 'learning_rate': 1.3333333333333333e-05, 'epoch': 0.08}
# {'loss': 3.3047, 'learning_rate': 1.3166666666666665e-05, 'epoch': 0.08}
# {'loss': 3.3984, 'learning_rate': 1.3000000000000001e-05, 'epoch': 0.08}
# {'loss': 3.4555, 'learning_rate': 1.2833333333333333e-05, 'epoch': 0.08}
# {'loss': 3.407, 'learning_rate': 1.2666666666666668e-05, 'epoch': 0.08}
# {'loss': 3.2637, 'learning_rate': 1.25e-05, 'epoch': 0.08}
# {'loss': 3.2457, 'learning_rate': 1.2333333333333334e-05, 'epoch': 0.08}
# {'loss': 3.4236, 'learning_rate': 1.2166666666666668e-05, 'epoch': 0.08}
# {'loss': 3.374, 'learning_rate': 1.2e-05, 'epoch': 0.08}
# {'loss': 3.3559, 'learning_rate': 1.1833333333333334e-05, 'epoch': 0.08}
# {'loss': 3.3916, 'learning_rate': 1.1666666666666668e-05, 'epoch': 0.08}
# {'loss': 3.4469, 'learning_rate': 1.1500000000000002e-05, 'epoch': 0.08}
# {'loss': 3.3746, 'learning_rate': 1.1333333333333334e-05, 'epoch': 0.08}
# {'loss': 3.225, 'learning_rate': 1.1166666666666668e-05, 'epoch': 0.08}
# {'loss': 3.2633, 'learning_rate': 1.1000000000000001e-05, 'epoch': 0.08}
# {'loss': 3.4525, 'learning_rate': 1.0833333333333334e-05, 'epoch': 0.08}
# {'loss': 3.2783, 'learning_rate': 1.0666666666666667e-05, 'epoch': 0.08}
# {'loss': 3.4572, 'learning_rate': 1.05e-05, 'epoch': 0.08}
# {'loss': 3.4781, 'learning_rate': 1.0333333333333333e-05, 'epoch': 0.08}
# {'loss': 3.4596, 'learning_rate': 1.0166666666666667e-05, 'epoch': 0.08}
# {'loss': 3.4814, 'learning_rate': 1e-05, 'epoch': 0.08}
# {'loss': 3.4342, 'learning_rate': 9.833333333333333e-06, 'epoch': 0.08}
# {'loss': 3.3621, 'learning_rate': 9.666666666666667e-06, 'epoch': 0.08}
# {'loss': 3.2904, 'learning_rate': 9.5e-06, 'epoch': 0.08}
# {'loss': 3.4373, 'learning_rate': 9.333333333333334e-06, 'epoch': 0.09}
# {'loss': 3.3346, 'learning_rate': 9.166666666666666e-06, 'epoch': 0.09}
# {'loss': 3.3707, 'learning_rate': 9e-06, 'epoch': 0.09}
# {'loss': 3.4199, 'learning_rate': 8.833333333333334e-06, 'epoch': 0.09}
# {'loss': 3.3932, 'learning_rate': 8.666666666666668e-06, 'epoch': 0.09}
# {'loss': 3.4326, 'learning_rate': 8.500000000000002e-06, 'epoch': 0.09}
# {'loss': 3.382, 'learning_rate': 8.333333333333334e-06, 'epoch': 0.09}
#  83%|████████████████████████████████▌      | 2500/3000 [29:30<05:05,  1.64it/s]***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:16<00:16,  8.28s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:33<00:11, 11.69s/it]
#
# {'eval_rouge-1': 32.06662, 'eval_rouge-2': 7.6433979999999995, 'eval_rouge-l': 24.927768000000004, 'eval_bleu-4': 0.03634798561941041, 'eval_runtime': 39.0628, 'eval_samples_per_second': 1.28, 'eval_steps_per_second': 0.102, 'epoch': 0.09}
#  83%|████████████████████████████████▌      | 2500/3000 [30:09<05:05,  1.64it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:35<00:00,  8.24s/it]
#                                                                                 Saving model checkpoint to ./output/tmp-checkpoint-2500
# {'loss': 3.4021, 'learning_rate': 8.166666666666668e-06, 'epoch': 0.09}
# {'loss': 3.3406, 'learning_rate': 8.000000000000001e-06, 'epoch': 0.09}
# {'loss': 3.4994, 'learning_rate': 7.833333333333333e-06, 'epoch': 0.09}
# {'loss': 3.2857, 'learning_rate': 7.666666666666667e-06, 'epoch': 0.09}
# {'loss': 3.341, 'learning_rate': 7.5e-06, 'epoch': 0.09}
# {'loss': 3.257, 'learning_rate': 7.333333333333334e-06, 'epoch': 0.09}
# {'loss': 3.415, 'learning_rate': 7.166666666666667e-06, 'epoch': 0.09}
# {'loss': 3.2906, 'learning_rate': 7.000000000000001e-06, 'epoch': 0.09}
# {'loss': 3.3359, 'learning_rate': 6.833333333333333e-06, 'epoch': 0.09}
# {'loss': 3.3439, 'learning_rate': 6.666666666666667e-06, 'epoch': 0.09}
# {'loss': 3.26, 'learning_rate': 6.5000000000000004e-06, 'epoch': 0.09}
# {'loss': 3.4229, 'learning_rate': 6.333333333333334e-06, 'epoch': 0.09}
# {'loss': 3.3154, 'learning_rate': 6.166666666666667e-06, 'epoch': 0.09}
# {'loss': 3.475, 'learning_rate': 6e-06, 'epoch': 0.09}
# {'loss': 3.493, 'learning_rate': 5.833333333333334e-06, 'epoch': 0.09}
# {'loss': 3.3201, 'learning_rate': 5.666666666666667e-06, 'epoch': 0.09}
# {'loss': 3.4352, 'learning_rate': 5.500000000000001e-06, 'epoch': 0.09}
# {'loss': 3.1855, 'learning_rate': 5.333333333333334e-06, 'epoch': 0.09}
# {'loss': 3.5014, 'learning_rate': 5.166666666666667e-06, 'epoch': 0.09}
# {'loss': 3.3355, 'learning_rate': 5e-06, 'epoch': 0.09}
# {'loss': 3.2486, 'learning_rate': 4.833333333333333e-06, 'epoch': 0.09}
# {'loss': 3.532, 'learning_rate': 4.666666666666667e-06, 'epoch': 0.09}
# {'loss': 3.3248, 'learning_rate': 4.5e-06, 'epoch': 0.1}
# {'loss': 3.2309, 'learning_rate': 4.333333333333334e-06, 'epoch': 0.1}
# {'loss': 3.3719, 'learning_rate': 4.166666666666667e-06, 'epoch': 0.1}
# {'loss': 3.3051, 'learning_rate': 4.000000000000001e-06, 'epoch': 0.1}
# {'loss': 3.3104, 'learning_rate': 3.833333333333334e-06, 'epoch': 0.1}
# {'loss': 3.4551, 'learning_rate': 3.666666666666667e-06, 'epoch': 0.1}
# {'loss': 3.41, 'learning_rate': 3.5000000000000004e-06, 'epoch': 0.1}
# {'loss': 3.2895, 'learning_rate': 3.3333333333333333e-06, 'epoch': 0.1}
# {'loss': 3.3309, 'learning_rate': 3.166666666666667e-06, 'epoch': 0.1}
# {'loss': 3.4174, 'learning_rate': 3e-06, 'epoch': 0.1}
# {'loss': 3.3947, 'learning_rate': 2.8333333333333335e-06, 'epoch': 0.1}
# {'loss': 3.4725, 'learning_rate': 2.666666666666667e-06, 'epoch': 0.1}
# {'loss': 3.4848, 'learning_rate': 2.5e-06, 'epoch': 0.1}
# {'loss': 3.357, 'learning_rate': 2.3333333333333336e-06, 'epoch': 0.1}
# {'loss': 3.4709, 'learning_rate': 2.166666666666667e-06, 'epoch': 0.1}
# {'loss': 3.3596, 'learning_rate': 2.0000000000000003e-06, 'epoch': 0.1}
# {'loss': 3.3514, 'learning_rate': 1.8333333333333335e-06, 'epoch': 0.1}
# {'loss': 3.3793, 'learning_rate': 1.6666666666666667e-06, 'epoch': 0.1}
# {'loss': 3.176, 'learning_rate': 1.5e-06, 'epoch': 0.1}
# {'loss': 3.393, 'learning_rate': 1.3333333333333334e-06, 'epoch': 0.1}
# {'loss': 3.5236, 'learning_rate': 1.1666666666666668e-06, 'epoch': 0.1}
# {'loss': 3.4021, 'learning_rate': 1.0000000000000002e-06, 'epoch': 0.1}
# {'loss': 3.4777, 'learning_rate': 8.333333333333333e-07, 'epoch': 0.1}
# {'loss': 3.3703, 'learning_rate': 6.666666666666667e-07, 'epoch': 0.1}
# {'loss': 3.4014, 'learning_rate': 5.000000000000001e-07, 'epoch': 0.1}
# {'loss': 3.3199, 'learning_rate': 3.3333333333333335e-07, 'epoch': 0.1}
# {'loss': 3.3203, 'learning_rate': 1.6666666666666668e-07, 'epoch': 0.1}
# {'loss': 3.425, 'learning_rate': 0.0, 'epoch': 0.1}
# 100%|███████████████████████████████████████| 3000/3000 [35:24<00:00,  1.58it/s]***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:03<00:03,  1.73s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:06<00:02,  2.32s/it]
#
# {'eval_rouge-1': 33.06869999999999, 'eval_rouge-2': 7.36442, 'eval_rouge-l': 25.163814000000002, 'eval_bleu-4': 0.03626155017341328, 'eval_runtime': 40.3895, 'eval_samples_per_second': 1.238, 'eval_steps_per_second': 0.099, 'epoch': 0.1}
# 100%|███████████████████████████████████████| 3000/3000 [36:04<00:00,  1.58it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:23<00:00,  7.62s/it]
#                                                                                 Saving model checkpoint to ./output/tmp-checkpoint-3000
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# {'train_runtime': 2164.5791, 'train_samples_per_second': 5.544, 'train_steps_per_second': 1.386, 'train_loss': 3.445546875, 'epoch': 0.1}
# 100%|███████████████████████████████████████| 3000/3000 [36:04<00:00,  1.39it/s]
# ***** Running Prediction *****
#   Num examples = 1070
#   Batch size = 16
# 100%|███████████████████████████████████████████| 67/67 [09:58<00:00,  8.94s/it]

# %% [markdown]
# ## 3. 使用微调的数据集进行推理
# 在完成微调任务之后，我们可以查看到 `output` 文件夹下多了很多个`checkpoint-*`的文件夹，这些文件夹代表了训练的轮数。
# 我们选择最后一轮的微调权重，并使用inference进行导入。

# %%
# !python inference_hf.py output/checkpoint-3000/ --prompt "类型#裙*版型#显瘦*材质#网纱*风格#性感*裙型#百褶*裙下摆#压褶*裙长#连衣裙*裙衣门襟#拉链*裙衣门襟#套头*裙款式#拼接*裙款式#拉链*裙款式#木耳边*裙款式#抽褶*裙款式#不规则"
# Out:
# /root/anaconda3/envs/tf1/lib/python3.11/site-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████████████| 7/7 [00:03<00:00,  2.11it/s]
# /root/anaconda3/envs/tf1/lib/python3.11/site-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Setting eos_token is not supported, use the default one.
# Setting pad_token is not supported, use the default one.
# Setting unk_token is not supported, use the default one.
# 这款连衣裙采用不规则的压褶设计，时尚感十足，能够很好的修饰身材，让身材更加修长，气质优雅。采用网纱拼接设计，增加了视觉的层次感，增添性感魅力。加上拉链套头设计，方便穿脱，不规则的裙摆，增添灵动感，搭配上木耳边装饰，增添层次感。

# %% [markdown]
# ## 4. Homework
# 集成webui
# 启动报错，更新组件版本
# `pip install pydantic==2.10.6`
#
# ### 修改后的代码
# web_demo_gradio.py
# ### webui 调用界面
#
# ![WebUI](./2025-08-07_174727.png)
