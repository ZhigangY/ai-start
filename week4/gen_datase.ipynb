# %% [markdown]
# ## 成品构造训练数据，采用本地Qwen3-32B 模型用LangChain

# %% [markdown]
# ## 定义变量

# %%
from openai import OpenAI

# 定义变量
model="Qwen3-32B"
base_url="http://192.168.121.59:9008/v1"
api_key="none"

# %% [markdown]
# ## 使用 LangChain 构造训练数据

# %%
from langchain_openai import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage
from langchain.prompts.chat import (
    ChatPromptTemplate,
    HumanMessagePromptTemplate,
    SystemMessagePromptTemplate,
)

chat = ChatOpenAI(base_url=base_url,
                  api_key=api_key,
                  model=model,
                  temperature=1,
                  max_tokens=4095)

# %% [markdown]
# ### 数据增强：构造多样化的提问方式

# %%
def generate_question_summary_pairs(content, summary):
    """
    生成20对提问和总结的配对。

    :param content: 内容（例如：“蒙卦”）。
    :param summary: 内容的总结。
    :return: 包含20对提问和总结的列表。
    """
    # 20种提问模板
    question_templates = [
        "{}代表什么？",
        "周易中的{}含义是什么？",
        "请解释一下{}。",
        "{}在周易中是什么象征？",
        "周易{}的深层含义是什么？",
        "{}和教育启蒙有什么联系？",
        "周易的{}讲述了什么？",
        "{}是怎样的一个卦象？",
        "{}在周易中怎样表达教育的概念？",
        "{}的基本意义是什么？",
        "周易中{}的解释是什么？",
        "{}在周易中代表了哪些方面？",
        "{}涉及哪些哲学思想？",
        "周易中{}的象征意义是什么？",
        "{}的主要讲述内容是什么？",
        "周易{}的核心思想是什么？",
        "{}和启蒙教育之间有何联系？",
        "在周易中，{}象征着什么？",
        "请描述{}的含义。",
        "{}在周易哲学中扮演什么角色？"
    ]

    # 使用content填充提问模板
    questions = [template.format(content) for template in question_templates]

    # 创建提问和总结的配对
    question_summary_pairs = [(question, summary) for question in questions]

    return question_summary_pairs

# %% [markdown]
# ## 自动化批量生成训练数据流水线

# %%
## 去掉双引号
def remove_all_quotes(s):
    if isinstance(s, str):
        return s.replace('"', '')
    return s  # 非字符串类型原样返回

# %%
## 按行分析LLM返回内容
def parse_content_summary_line_by_line(text):
    content = None
    summary_lines = []
    in_summary = False
    in_quote = False

    # 按行分割
    lines = text.splitlines()

    for line in lines:
        line = line.strip()

        # 跳过空行和 think 标签
        if not line or line.startswith('<think>') or line.endswith('</think>'):
            continue

        # 处理 content
        if line.startswith('content:') and not content:
            # 提取 content: 后面双引号中的内容
            start = line.find('"')
            if start != -1:
                end = line.find('"', start + 1)
                if end != -1:
                    content = line[start + 1:end]
                else:
                    # 只有开头引号，没有闭合 → 取到行尾（去掉引号）
                    content = line[start + 1:]

        # 处理 summary
        if line.startswith('summary:') and not in_summary:
            in_summary = True
            # 找到 summary: 后的第一个 "
            start = line.find('"')
            if start != -1:
                # 从 " 之后的内容开始收集
                part = line[start + 1:]
                if part:
                    summary_lines.append(part)
                in_quote = True
            else:
                # 没有引号，直接从后面开始
                after = line[8:].strip()  # len('summary:') == 8
                if after:
                    summary_lines.append(after)
                in_quote = False
        elif in_summary:
            # 如果 summary 已开始，继续收集所有非空行，直到我们认为结束
            # 判断是否到了外部的 '''（常见于多行字符串结尾）
            if "'''" in line or '"""' in line or line.startswith('</think>'):
                break  # 结束
            summary_lines.append(line)

    summary = '\n'.join(summary_lines) if summary_lines else None

    return  remove_all_quotes(content), remove_all_quotes(summary)

# %%
def gen_data(raw_content):
    """
    使用LLM调用处理单个数据样例。

    :param raw_content: 原始数据样例。
    :return: LLM模型生成的内容。
    """
    # 系统消息定义背景和任务
    system_message = SystemMessage(
        content="""/no_think 
        你是中国古典哲学大师，尤其擅长周易的哲学解读。

        接下来，你收到的都是关于周易卦象的解释，你需要整理润色，并生成用于大模型训练的内容和格式。

        示例输入：

        师卦，此卦是异卦相叠，下卦为坎，上卦为坤。“师”指军队。坎为水、为险；坤为地、为顺，喻寓兵于农。兵凶战危，用兵乃圣人不得已而为之，但它可以顺利无阻碍地解决矛盾，因为顺乎形势，师出有名，故能化凶为吉。占得此卦，对于军事上率师出征非常有利，必无灾祸。师卦是天马出群之卦，以寡伏众之象。
        师卦位于讼卦之后，《序卦》之中这样解释道：“讼必有众起，故受之以师。师者，众也。”争讼的人越来越多，以致形成了军队。

        期待结果：

        content:"师卦"
        summary:"在周易中，师卦是一个极具深意的卦象，它由两个异卦相叠组成：下卦坎（水）和上卦坤（地）。这一卦象代表“师”，即军队，寓意着兵力和农力的结合。在这里，坎卦象征着水和险难，而坤卦象征着地和顺从，暗示着通过将军事力量安置于民间，可以在必要时顺利调动。

        师卦的核心哲学是：虽然兵力代表着危险和战争，但其使用应当是圣人不得已而为之的最后手段。在正确的情况下，军事力量可以顺应形势，将危险转化为吉祥。因此，在军事策略上，此卦象征着出征将会顺利，无灾祸。

        师卦紧随讼卦（争讼卦），在《序卦》中解释为“讼必有众起，故受之以师”。这意味着争端激化至众多人群的参与，形成了类似军队的集体力量。"

        返回格式要求：
        content:"{卦名}"
        summary:"{内容}"
        """
    )

    # 人类消息包含原始数据样例
    human_message = HumanMessage(
        content=raw_content
    )

    # 构建消息列表并进行模型调用
    messages = [system_message, human_message]
    ai_message = chat(messages)

    return ai_message.content

# %%
import csv
import datetime
import os

def main():
    # 确保 data 目录存在
    if not os.path.exists('data'):
        os.makedirs('data')

    # 解析 data/raw_data.txt 得到 raw_content_data 列表
    raw_content_data = []
    with open('data/raw_data.txt', 'r', encoding='utf-8') as file:
        content = file.read()
        data_samples = content.split('\n\n')
        for sample in data_samples:
            cleaned_sample = sample.strip()
            if cleaned_sample:
                raw_content_data.append(cleaned_sample)

    # 创建带有时间戳的CSV文件名
    timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    filename = f"data/zhouyi_dataset_{timestamp}.csv"

    # 创建CSV文件并写入标题行
    with open(filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['content', 'summary'])

        # 循环遍历 raw_content_data 数据样例
        for raw_content in raw_content_data:
            # 调用 gen_data 方法得到 ai_message_content
            ai_message_content = gen_data(raw_content)

            # 解析 ai_message_content 得到 content 和 summary
            content, summary = parse_content_summary_line_by_line(ai_message_content)
            
            print("Content:", content)
            print("Summary:", summary)

            # 调用 generate_question_summary_pairs 得到20组 pairs
            pairs = generate_question_summary_pairs(content, summary)

            # 将 pairs 写入 csv 文件
            for pair in pairs:
                writer.writerow(pair)

# %%
# 执行主函数
main()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_19968\341638561.py:42: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   ai_message = chat(messages)
# Content: 蒙卦
# Summary: 在周易中，蒙卦象征着启蒙与迷茫的双重状态，其卦象为下坎（水）上艮（山），意味着山下泉水初涌，象征事物初始阶段的混沌与未知。《易经》中，蒙卦代表智慧尚未开启、内心蒙昧的状态，强调教育与引导的重要性。
# 蒙卦卦辞中提到：“匪我求童蒙，童蒙求我”，揭示了启蒙的本质：并非主动去求教于蒙昧者，而是蒙昧者主动寻求开导。此卦强调敬畏与真诚，若占卜时态度不敬，反会被忽视。因此，《象辞》以“山下出泉”象征启蒙的开始，主张君子应效法山泉之坚定与果敢，以行动培养德行。
# 传统解释中，蒙卦为离宫四世卦，有回环往复之意，象征事物在初期多疑虑、困惑，但只要时机得当，行动果断，便有启蒙通达之可能。邵雍称其为“智慧未开，蒙昧闭塞”，若能顺从贤师良友，则可开智亨通。傅佩荣则强调蓄德用世，主张在德行积累之后方能有所作为。
# 从运势上看，蒙卦象征初时迷惑，需耐心等待良机，多听他人意见。在事业上，混乱无序中需有勇有决，以坚定的行动扭转局面，并通过教育提升自我。经商方面应谨慎行事，树立信誉。婚恋中应注重品德考察，避免物质诱惑。总体而言，蒙卦虽属启蒙之象，然亦含凶机，若能顺时顺师，必有所成。
# Content: 屯卦
# Summary: 在《周易》中，屯卦象征万物初生之艰难，是坎（水）上震（雷）下所组成的卦象，代表雷雨交加、环境险恶的状态。其卦名“屯”意为“难”，象征着万事万物在萌发之初，面临着重重阻碍与挑战，必须刚毅果敢、持之以恒，方能突破困境，逐步通达。
# 屯卦的卦辞为：“元，亨，利，贞。勿用，有攸往，利建侯。”意思是初始吉利，通达顺利，适宜占卜，但不宜贸然行动，应守而不进，利于建立诸侯之功。《象辞》曰：“云雷屯，君子以经纶。”说明君子应效法云雷之象，以温和的恩泽与果断的行动治理国家，化险为夷。
# 哲学层面，屯卦蕴含“万物始生、先劳后逸”的深意。邵雍解其为“万物始生，开始困难；先劳后逸，苦尽甘来”，表明艰难是成功的前提，唯有经过努力与坚持，才能迎来光明的未来。得此卦者，宜守不宜进，须耐心应对困境，排除障碍，才能最终通达。
# 《断易天机》认为屯卦为“动而逢险”，需刚毅果敢方可吉利。而傅佩荣则从时运、财运、家宅、身体等多方面指出其象征意义，强调“宜守不宜进”。
# 整体而言，屯卦是困境与潜力并存的象征，提醒人们在逆境中保持坚韧，积极进取，在等待时机的同时不断积蓄力量，终将苦尽甘来，迎来新生与成功。
# Content: 需卦
# Summary: 在周易中，需卦是一个寓意深远的卦象，由上卦坎（水）与下卦乾（天）相叠而成，属于坤宫游魂卦。需，有等待、期盼之意，象征事物尚未成熟，需耐心以待时机。坎为险，乾为健，此卦象示人在刚健之时遇到险阻，应当以沉稳、理智的态度去应对，不可贸然行动，应审时度势，待机而动。
# 《象辞》曰：“云上于天，需；君子以饮食宴乐。”此象表明云虽高悬天上，尚未降雨，象征时机未至，须等待适宜的条件。君子见此象，当知需静以待时，安于饮食娱乐，养精蓄锐，以待其时。因此，需卦传达出“待时而动”的智慧哲理，强调“大器晚成”的人生观。
# 从传统解卦来看，需卦象示云登于天而未雨，意味着不能急进，需等待时机成熟。无论是事业、财运、婚恋，还是个人求名求运，皆需耐心等待，不可躁进。在事业上，应审时度势，静观其变，以智慧与信念稳中求进；在婚恋上，应谨慎以待，以柔克刚，培养感情，方能有良好结果。
# 邵雍释此卦为“坎陷当前，遇阻不进”，强调在面临困难时，应保持坚定信念，耐心等待。傅佩荣则指出，需卦预示时机尚未成熟，宜守不宜动，时运、财运均需静候良机。
# 综上所述，需卦所传达的核心思想是：人生中难免遭遇阻碍，关键在于静待时机，以柔克刚，以智取胜，最终必能成就大事。”
# Content: 讼卦
# Summary: 在《周易》中，讼卦由下坎（水）上乾（天）组成，属于乾上坎下的卦象。这一卦象象征着争讼与冲突，寓意着刚健与险陷的对立与争执。坎为险、乾为健，二者性质相悖，水向上流，天向下倾，彼此违行，因而产生争讼。讼卦是与需卦互为“综卦”的关系，象征着争执的起点。
# 讼卦的核心哲学是：争讼并非善事，虽中间可能因有诚信而吉利，但最终多趋于凶险。占得此卦，说明当前局势中不宜争强斗胜，而应谋定而后动，防患于未然。《象辞》中强调，“君子以做事谋始”，警示人在行事之初便应谨慎谋划，避免纠纷。
# 《断易天机》指出，讼卦是乾上坎下的离宫游魂卦。乾为刚，坎为险，刚与险相遇，必生争执，故多不吉。北宋易学家邵雍认为，此卦如“天高水深，达远不亲”，提醒人在争端中要退守、慎谋，以免招致不测之祸。
# 从现实角度看，得此卦者往往心绪不安，凡事不顺，易与人争讼。此时应修身养性，审慎处事。在事业上宜退而避让，避免卷入不必要的冲突；在经商上应秉持公义，和气生财；在求名上则不宜急功近利，而应隐忍自励，积蓄实力；在婚恋中虽不完美，但如能彼此理解、以和为贵，亦可共处。
# 决策方面，讼卦提醒人应安于本分，知足常乐，莫因争强好胜而惹来灾祸。若能顺应自然，接受现实，引以为戒，终可转危为安，成就一番事业。
# ---
# 是否需要我继续整理其他卦象的解读？
# Content: 师卦
# Summary: 师卦在《周易》六十四卦中具有重要的军事与组织哲学意义。其卦象为坤上坎下，坎为水、为险，坤为地、为顺，象征着在顺从之中蕴藏危机，兵事虽险，但若依正道而行，必能化凶为吉。卦辞「贞，丈人吉，无咎」强调在军事行动中，必须以正道为本，并由德高望重的长者统率军队，方可吉祥无咎。《象辞》曰「地中有水，师。君子以容民畜众」，喻示军队的运作应如大地涵养江河，容纳民众，凝聚众力。
# 《断易天机》认为师卦为坎宫归魂卦，寓意兵众需有良将统领，方可无咎。邵雍解卦指出，此卦虽忧劳动众，却蕴含变化，唯有公正无私，才能排除万难。傅佩荣则从时运、财运、家宅与身体等角度解析，强调包容与等待的智慧。
# 整体而言，师卦强调在面对复杂局势和外部威胁时，必须具备组织能力、领导力与正道精神。在事业上，宜合作谨慎；在财运上，应善自珍惜；在婚恋上，需专一专注。而从决策角度看，师卦提醒我们在追求事业的过程中，应沉稳老成，不贪功，以中正之道应对万难，方能实现长远目标。
# Content: 比卦
# Summary: 在周易中，比卦是一个象征亲密、相辅相成的卦象，由下卦坤（地）和上卦坎（水）构成，代表“比”，即相亲相附之意。卦象中，水依附于地，大地容纳江河，寓意着万物相互依存、团结共济。
# 比卦的核心意义是“比”——人与人之间的亲近、信任与合作。正如《象辞》所言：“地上有水，比”，此卦象征着一种亲密无间、互相扶持的和谐关系。在政治治理中，象征君主以宽厚仁爱之心与诸侯亲近；在个人生活中，则意味着得遇贵人相助、众人力挺，事业可成，婚恋幸福。
# 此卦为坤宫归魂卦，与师卦互为综卦，一者讲战争冲突，一者讲和顺相亲，形成鲜明对比。得此卦者，谋事顺遂，人际关系融洽，有朋友之助、众人之功，可成大事，荣显之极。
# 邵雍指出，比卦象征水行地上，人心向善，百事无忧。傅佩荣则认为，此卦象征众人庆贺、荣宠至极，无论时运、财运、家宅、身体皆有吉祥之兆。
# 在事业上，比卦提示应以诚恳、信任的态度待人，宽厚正直，主动向德才兼备者学习；在经商上，需注重合作、诚信经营，避免唯利是图；在求名与婚恋上，则预示有望成事，婚配美满。
# 总体而言，比卦象征和谐亲密的群体关系，是人生顺遂、人心所向之象，贵在速行、速决，不可迟疑拖延，更应谨慎交友，善择贤者为伍，方能终生受益。
# Content: 坤卦
# Summary: 在《周易》中，坤卦是六十四卦之一，卦象为坤上坤下，象征纯阴之地，代表大地，寓意柔顺、包容与承载。坤卦的基本精神是“元，亨，利牝马之贞”，即万物开始而顺利，利于像雌马那样柔顺而贞正。坤卦的哲学意义在于强调顺应天道、厚德载物，其象曰：“地势坤，君子以厚德载物”，表明君子应当效法大地之德，以柔顺包容的心态承担重大责任。
# 坤卦在行旅、求财、婚配、事业等方面均有吉象，尤其是西南方向利于获得助力与财富，东北则可能有所损失。然而，占得此卦者宜静不宜动，需顺从时势，谨慎行事，不可冒进，应注重团结合作，借力于他人。
# 坤卦的象征意义为“先迷后得”，说明起初或许迷失方向，但最终能寻得正道。其核心思想在于以柔克刚、静守以应动，体现了中国古典哲学中柔中有刚、顺中有定的处世智慧。传统解卦也强调坤为母性大地，依乾而行，温顺包容，象征生育与滋养万物的力量。得此卦者宜修身养德，宽厚待人，以柔顺之德成就大事。
# Content: 乾卦
# Summary: 乾卦是《周易》六十四卦之首，由六个阳爻组成，纯阳刚健，象征天。乾卦卦辞为‘元，亨，利，贞’，寓意大吉大利，象征万物发育运行之始，顺乎天道则通达顺利。
# 《象辞》有言：“天行健，君子以自强不息。”乾卦揭示天道运行刚健不息的规律，激励君子效法天德，自强奋进、永不停息。
# 乾卦的核心哲学在于强调刚强与持续的力量，象征阳气之盛，如飞龙在天，志在高远。事业如日中天，名利双收，但须谨防过刚易折、盛极必衰之理，强调在成功中保持谦逊，顺天应时，谨言慎行，方能持久。
# 乾卦告诫人要不断修养德行，积累学问，坚定信念，自强不息，方能在人生各个领域中取得成功。无论是求名、经商、婚恋，皆可得利，但女性得此卦则需注意过于刚直，应适当调和刚柔。
# 此卦象征着生命的力量与进取的精神，是人生奋发向上的典范与起点。
